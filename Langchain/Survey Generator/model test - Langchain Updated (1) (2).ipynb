# %%
import warnings, csv, os, sys
import pandas as pd
from typing import List
warnings.filterwarnings("ignore")
from langchain_openai import ChatOpenAI
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    ChatPromptTemplate
)
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain.output_parsers.openai_functions import JsonKeyOutputFunctionsParser

# %%
def write_csv(output_file, data):
    with open(output_file, 'a', newline='', encoding='utf-8') as outfile:  
        writer = csv.writer(outfile)
        writer.writerow(data)

# %%
#variables

model_name = 'gpt-4-1106-preview'  #gpt model name
audience = ' US owners of 1 dog'  #audience
output_file = 'output.csv'

#you can change questions and traits/count as you want, this part has become dynamic in this notebook.
questions = [
'How old is your dog (in # of years)?',
'What is your dogs primary breed?',
'Approximately how much does your dog weigh (in pounds)?',
'What is your dogs name?',
'What was the inspiration for that name?',
'What is the most common nickname (if any) that you use for your dog?',
'When did you get your dog?',
'Did you adopt your dog?',
'How old was your dog when you got him/her? Provide estimated number of months old.',
'How did you feel the first time you met your dog?',
'How has your dog changed your outlook on life?',
'On a scale of 1-5, where 1 is not at all important and 5 is very important, how important is your dogs happiness to your overall well-being?',
'Choose the term that best describes your dogs relationship with you.',
'Why did you choose that term?',
'What is the most recent command or trick your dog has learned, and how long did it take to train?',
'How many hours a day does your dog typically sleep and where does your dog usually sleep in your home?',
'Have you shopped for your dog online in the past year?',
'Over the past year, approximately how much did you spend on your dog? Provide total $ amount.',
'Over the past year, approximately what percent of the money you spent on your dog was paid to your veterinarian? Choose a percent from 0% to 100%.',
'Over the past year, approximately what percent of the money you spent on your dog was on dog food? Choose a percent from 0% to 100%.',
'In March, approximately much money did you spend on your dog? Provide estimated total $ amount.',
'How did the amount of money you spent on your dog in March compare with February?',
'How often do you purchase dog food?',
'Do you primarily feed your dog dry food, wet food, or a mix?',
'Which of the following statements best describes your level of familiarity of your dogs primary food brand?',
'On a scale of 1-5, where 1 is not at all important and 5 is very important, how important is the following in choosing your primary dog food brand?',
'What dog food brand do you give your dog the most?',
'What are the main 2-3 reasons you choose this brand?',
'On a scale of 1-5, where 1 is not at all satisfied and 5 is very satisfied, how satisfied are you with the following for your primary dog food brand?',
'How many times a day does your dog typically go out for a walk?',
'How (if at all) have recent events affected how you interact with your dog?',
'What events are affecting your interaction level most?',
'Are you planning to watch the Summer Olympics with your dog?',
'Are you planning to travel this Spring with your dog?',
'If planning to travel this Spring with your dog, which is your preferred method of transportation? Select the best option.',
'What is your gender?',
'What is your age?',
'How many people, including yourself, live in your household?',
'What is the highest level of education you have completed?',
'What is your current employment status?',
'What is your total annual household income before taxes?',
'In which city and state do you currently reside?'
]

traits_and_counts = [
    ('Women aged 60+', 2)
]

# %%
# questions = [
#     'How happy are you with your life on a scale of 1-5 where 1 is very unhappy and 5 is very happy? (#)',
#     'What are the few tech tools that you use daily?',
#     'What is your profession?',
# ]

# traits_and_counts = [
#     ('Men being currently employed', 4),
#     ('Women being currently employed', 3)
# ]

# %%
# This block of code is not needed, it is there to know how function calling works.

# To learn more about function calling, check this out https://www.datacamp.com/tutorial/open-ai-function-calling-tutorial
#Answer is the class which contains response given by each user, it also contain traits to know which person answered the questions.
#llm is inteligent enough to give unique response each time based on the given system and user prompt, we should not worry about it.
class Answer(BaseModel):
    """Human-like set of answers told by each person while being surveyed. 
    Each person should have their own unique set of answers that should be different from other person's set of answers."""

    answer1: str = Field(description="This is the human like answer to Question1.")
    answer2: str = Field(description="This is the human like answer to Question2.")
    answer3: str = Field(description="This is the human like answer to Question3.")
    answer4: str = Field(description="This is the human like answer to Question4.")
    traits: str = Field(description="This is the trait of the person.")
    
    
    
#list of answers, the formatted list that the llm model will generate which contains dictionaries of Answer class
#llm model will make sure that each dictionary in the list is unique from each other as it will treat the list like list of human responses.
class Answers(BaseModel):
    """Human-like survey answers to tell user."""

    answer: List[Answer]

# %%
# This is standard pattern of list of functions used for function calling.
# To know the pattern, you can print out openai_functions variable in previous New.ipynb file
# This function is responsible to give the output list of answers of each human that we want, based on the parameters provided.
# To learn more about function calling, check this out https://www.datacamp.com/tutorial/open-ai-function-calling-tutorial
def create_openai_functions(questions: List):
    fn  = [{'name': 'Answers',
            'description': 'Human-like survey answers to tell user.',
            'parameters': {'type': 'object',
            'properties': {'answer': {'type': 'array',
                'items': {'description': "Human-like set of answers told by each person while being surveyed. \nEach person should have their own unique set of answers that should be different from other person's set of answers.",
                'type': 'object',
                'properties': {
                'traits': {'description': 'This is the trait of the person.',
                    'type': 'string'}},
                'required': ['traits']}}},
            'required': ['answer']}}]
    answers = fn[0]['parameters']['properties']['answer']['items']['properties']
    required = fn[0]['parameters']['properties']['answer']['items']['required']
    for ind, _ in enumerate(questions, 1):
        answers[f'answer{ind}'] = {'description': f'This is the human like answer to Question{ind}.', 'type': 'string'}
        required.append(f'answer{ind}')
    return fn

# %%
#sample openai function example
openai_functions = create_openai_functions(questions)
openai_functions
# Out:
# [{'name': 'Answers',
#   'description': 'Human-like survey answers to tell user.',
#   'parameters': {'type': 'object',
#    'properties': {'answer': {'type': 'array',
#      'items': {'description': "Human-like set of answers told by each person while being surveyed. \nEach person should have their own unique set of answers that should be different from other person's set of answers.",
#       'type': 'object',
#       'properties': {'traits': {'description': 'This is the trait of the person.',
#         'type': 'string'},
#        'answer1': {'description': 'This is the human like answer to Question1.',
#         'type': 'string'},
#        'answer2': {'description': 'This is the human like answer to Question2.',
#         'type': 'string'},
#        'answer3': {'description': 'This is the human like answer to Question3.',
#         'type': 'string'},
#        'answer4': {'description': 'This is the human like answer to Question4.',
#         'type': 'string'},
#        'answer5': {'description': 'This is the human like answer to Question5.',
#         'type': 'string'},
#        'answer6': {'description': 'This is the human like answer to Question6.',
#         'type': 'string'},
#        'answer7': {'description': 'This is the human like answer to Question7.',
#         'type': 'string'},
#        'answer8': {'description': 'This is the human like answer to Question8.',
#         'type': 'string'},
#        'answer9': {'description': 'This is the human like answer to Question9.',
#         'type': 'string'},
#        'answer10': {'description': 'This is the human like answer to Question10.',
#         'type': 'string'},
#        'answer11': {'description': 'This is the human like answer to Question11.',
#         'type': 'string'},
#        'answer12': {'description': 'This is the human like answer to Question12.',
#         'type': 'string'},
#        'answer13': {'description': 'This is the human like answer to Question13.',
#         'type': 'string'},
#        'answer14': {'description': 'This is the human like answer to Question14.',
#         'type': 'string'},
#        'answer15': {'description': 'This is the human like answer to Question15.',
#         'type': 'string'},
#        'answer16': {'description': 'This is the human like answer to Question16.',
#         'type': 'string'},
#        'answer17': {'description': 'This is the human like answer to Question17.',
#         'type': 'string'},
#        'answer18': {'description': 'This is the human like answer to Question18.',
#         'type': 'string'},
#        'answer19': {'description': 'This is the human like answer to Question19.',
#         'type': 'string'},
#        'answer20': {'description': 'This is the human like answer to Question20.',
#         'type': 'string'},
#        'answer21': {'description': 'This is the human like answer to Question21.',
#         'type': 'string'},
#        'answer22': {'description': 'This is the human like answer to Question22.',
#         'type': 'string'},
#        'answer23': {'description': 'This is the human like answer to Question23.',
#         'type': 'string'},
#        'answer24': {'description': 'This is the human like answer to Question24.',
#         'type': 'string'},
#        'answer25': {'description': 'This is the human like answer to Question25.',
#         'type': 'string'},
#        'answer26': {'description': 'This is the human like answer to Question26.',
#         'type': 'string'},
#        'answer27': {'description': 'This is the human like answer to Question27.',
#         'type': 'string'},
#        'answer28': {'description': 'This is the human like answer to Question28.',
#         'type': 'string'},
#        'answer29': {'description': 'This is the human like answer to Question29.',
#         'type': 'string'},
#        'answer30': {'description': 'This is the human like answer to Question30.',
#         'type': 'string'},
#        'answer31': {'description': 'This is the human like answer to Question31.',
#         'type': 'string'},
#        'answer32': {'description': 'This is the human like answer to Question32.',
#         'type': 'string'},
#        'answer33': {'description': 'This is the human like answer to Question33.',
#         'type': 'string'},
#        'answer34': {'description': 'This is the human like answer to Question34.',
#         'type': 'string'},
#        'answer35': {'description': 'This is the human like answer to Question35.',
#         'type': 'string'},
#        'answer36': {'description': 'This is the human like answer to Question36.',
#         'type': 'string'},
#        'answer37': {'description': 'This is the human like answer to Question37.',
#         'type': 'string'},
#        'answer38': {'description': 'This is the human like answer to Question38.',
#         'type': 'string'},
#        'answer39': {'description': 'This is the human like answer to Question39.',
#         'type': 'string'},
#        'answer40': {'description': 'This is the human like answer to Question40.',
#         'type': 'string'},
#        'answer41': {'description': 'This is the human like answer to Question41.',
#         'type': 'string'},
#        'answer42': {'description': 'This is the human like answer to Question42.',
#         'type': 'string'}},
#       'required': ['traits',
#        'answer1',
#        'answer2',
#        'answer3',
#        'answer4',
#        'answer5',
#        'answer6',
#        'answer7',
#        'answer8',
#        'answer9',
#        'answer10',
#        'answer11',
#        'answer12',
#        'answer13',
#        'answer14',
#        'answer15',
#        'answer16',
#        'answer17',
#        'answer18',
#        'answer19',
#        'answer20',
#        'answer21',
#        'answer22',
#        'answer23',
#        'answer24',
#        'answer25',
#        'answer26',
#        'answer27',
#        'answer28',
#        'answer29',
#        'answer30',
#        'answer31',
#        'answer32',
#        'answer33',
#        'answer34',
#        'answer35',
#        'answer36',
#        'answer37',
#        'answer38',
#        'answer39',
#        'answer40',
#        'answer41',
#        'answer42']}}},
#    'required': ['answer']}}]

# %%
parser = JsonKeyOutputFunctionsParser(key_name="answer")  # to parse the output, it will return list of answers based on function calling

# %%
#bind openai_functions to llm for function calling
llm = ChatOpenAI(
    temperature=0.9,
    model_name=model_name
).bind(functions=openai_functions)

# %%
#this is default system message, you can change it based on your need.
system_message = """
You are a survey answering bot that generates answers like a survey when questions are asked. The answer should be made as if you are a human. 
Give answers assuming you are a new human with different lifestyles while giving answers.
Give answers with new thoughts, new ideas, new moods, you can also choose to answer very rudely, but the main idea is to be random, do not try to repeat same answers since humans have different answers with different answer style.
While giving answers, you should be as creative as possible and you should deviate your answers as much as possible from previous answers.
In every answer, change styles of answers, change average sentence lengths of answer, change fk_grade_level of sentences of answer. Make it different from previous answers. But also make sure it is the answer given by a human. So, don't make it seem like it is AI generated. Add both simple and fancy words.
In 1 answer, give your answers assuming you are having a worse life, in another answer, give your answers assuming you are having best life. like this, keep on changing the lifestyle of human that you are.
Avoid same repeated answers as much as possible.
Do no repeat same pattern in each answers. Give short answers sometimes and sometimes long answers, be random.
Since, human can give both positive and negative answers, you should follow the same principles.
Your answers should be descriptive just like human answers.
Each set of answers should be different from another set of answers. 
If you are asked about 'top few things' or 'few things', each answers should have random number of comma separated sentences. For example:
sentence1, sentence2, and sentence3. (3 sentences)
sentence1. (1 sentence)
sentence1, sentence2, sentence3, sentence4, and sentence5. (5 sentences)
sentence1, sentence2. (2 sentences)
sentence1, sentence2, sentence3, and sentence4. (4 sentences)


If the output asks for a monetary output give just the dollar amount and no text before or after it unless prompted to do so. So for example if the answer is $40 just give $40.
If the output asks for a decimal output give just the value and no text before or after it unless prompted to do so. So for example if the answer is 40.5 just give 40.5.
If you are asked a question like where do you live? Be sure to just answer the place that you live. No text before or after it is needed unless prompted to do so.
If the answer is asking for a percentage output just give the value. So if the answer is 45% just give 45%. Do not give any text before or after that unless prompted to do so.
"""

# %%
#chat template
prompt = ChatPromptTemplate.from_messages(
    [("system", system_message), ("user", "{input}")]
)

# %%
#chain using prompt, llm and parser
#it uses the prompt with llm and generate the answer based on the parser
# chain = prompt | llm | parser

chain = prompt | llm

# %%
total_processed_row = 0  #total row processed
total_remaining_surveyed = 0  #total people remaining to be surveyed
person_number = 0  #person count
traits_dict = {}


for dta in traits_and_counts:
    traits_dict[dta[0]] = int(dta[1])  #creating dict of traits and counts
    total_remaining_surveyed += int(dta[1])  #total people remaining to be surveyed
        
if output_file not in os.listdir():  #if csv is not available
    write_csv(output_file, ['Traits', 'Person Number']+questions)
else: #if csv already exists
    df = pd.read_csv(output_file)
    old_traits_dict = df['Traits'].value_counts().to_dict() #get traits/counts of already surveyed people in csv
    for k,v in old_traits_dict.items():
        traits_dict[k] = traits_dict[k]-v
        total_remaining_surveyed = int(total_remaining_surveyed - v)  #subtracting from the people that are already in csv. suppose 7 needed, 3 are already in csv, it will only process 4
        person_number += v #increasing the person number
        
        
print("Remaining Traits/counts dict:", traits_dict)
print("Total remaining people to be surveyed:", total_remaining_surveyed)
print()

if total_remaining_surveyed <= 0:
    print("All the people are surveyed, if you want to increase survey count, increase the count in traits_and_counts variable at top")
    sys.exit()
    
    
while True:
    total_surveyed = sum([counts for _, counts in traits_dict.items()])
    input_message = f"Generate survey answers from {total_surveyed} people.\nAll of the surveyed people are {audience}\n"
    for traits, counts in traits_dict.items():
        if counts <= 0:
            continue
        input_message += f'{counts} of the surveyed people have this trait: {traits}\n'
    input_message += f'Extremely Important Note: You must compulsory give answers to all the questions provided below. Do not skip any questions.\n'
    for ind, question in enumerate(questions, 1):
        input_message += f'Question{ind}: {questions[ind-1]}\n'
    
    responses = chain.invoke({"input": input_message})
    final_responses = []
    for data in responses:
        if type(data) == dict:
            final_responses.append(data)
    print(len(final_responses))
    print(final_responses)
    print()
    for data in final_responses:
        person_number += 1
        lst = [data['traits'], person_number]
        for ind, question in enumerate(questions):
            lst.append(data[f'answer{ind+1}'])
        write_csv(output_file, lst)
    for data in final_responses:
        traits_dict[data['traits']] = traits_dict[data['traits']]-1
    total_processed_row += len(final_responses)
    if total_processed_row == total_remaining_surveyed:
        break
# Out:
# Remaining Traits/counts dict: {'Women aged 60+': 100}
# Total remaining people to be surveyed: 100
#
# 3
# [{'traits': 'Women aged 60+', 'answer1': '6', 'answer2': 'Beagle', 'answer3': '22', 'answer4': 'Buddy', 'answer5': "It's the name he had at the shelter, and we loved it.", 'answer6': 'Bud', 'answer7': '2018', 'answer8': 'Yes', 'answer9': '4', 'answer10': 'It was love at first sight!', 'answer11': "She's taught me to enjoy the simple things in life.", 'answer12': '5', 'answer13': 'Best friend', 'answer14': "Because he's loyal and always by my side.", 'answer15': 'Sit and stay, it took about 2 weeks.', 'answer16': 'He sleeps for about 14 hours, usually on his bed in the living room.', 'answer17': 'No', 'answer18': '450', 'answer19': '25%', 'answer20': '40%', 'answer21': '35', 'answer22': 'Spent a little more in March due to buying a new bed and some toys.', 'answer23': 'Monthly', 'answer24': 'Dry food', 'answer25': 'I am very familiar with the brand.', 'answer26': '5', 'answer27': 'Purina', 'answer28': 'High quality ingredients, recommended by vet, and Buddy loves it.', 'answer29': '4', 'answer30': '3', 'answer31': "We've spent more quality time together.", 'answer32': 'The COVID-19 pandemic', 'answer33': 'No', 'answer34': 'No plans as of now.', 'answer35': 'Not applicable', 'answer36': 'Female', 'answer37': '64', 'answer38': '1', 'answer39': 'Some college', 'answer40': 'Retired', 'answer41': '30000', 'answer42': 'Sarasota, Florida'}, {'traits': 'Women aged 60+', 'answer1': '3', 'answer2': 'Labrador Retriever', 'answer3': '75', 'answer4': 'Sadie', 'answer5': 'She seemed so sad in her kennel, I wanted a happy name to change that.', 'answer6': 'Sades', 'answer7': '2020', 'answer8': 'Yes', 'answer9': '7', 'answer10': 'Overwhelmed with joy.', 'answer11': "I've become more outgoing and adventurous.", 'answer12': '5', 'answer13': 'Companion', 'answer14': "She's always by my side, more than just a pet.", 'answer15': 'Shake paw took us around a month.', 'answer16': 'She sleeps around 12 hours, in her bed next to mine.', 'answer17': 'Yes', 'answer18': '600', 'answer19': '20%', 'answer20': '60%', 'answer21': '55', 'answer22': 'Increased somewhat due to treating a minor injury.', 'answer23': 'Every two weeks', 'answer24': 'Mix', 'answer25': 'I know it well enough, my vet suggested it.', 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': 'Trustworthy brand, health benefits, and Sadie likes it.', 'answer29': '5', 'answer30': '2', 'answer31': "We've been taking longer walks.", 'answer32': 'COVID-19 and retirement', 'answer33': "Perhaps, if it's on TV.", 'answer34': 'Yes, a short road trip.', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '68', 'answer38': '2', 'answer39': "Bachelor's degree", 'answer40': 'Part-time', 'answer41': '50000', 'answer42': 'Boulder, Colorado'}, {'traits': 'Women aged 60+', 'answer1': '4', 'answer2': 'Golden Retriever', 'answer3': '68', 'answer4': 'Max', 'answer5': 'After my favorite book character.', 'answer6': 'Maxie', 'answer7': '2017', 'answer8': 'No', 'answer9': '10', 'answer10': "I was ecstatic, couldn't wait to bring him home.", 'answer11': "I'm more patient and caring now.", 'answer12': '5', 'answer13': 'Family', 'answer14': "He's not just a pet, he's part of my life.", 'answer15': 'He learned to fetch in just a week!', 'answer16': 'Around 10 hours, and he has multiple spots, but loves the foot of my bed.', 'answer17': 'Yes', 'answer18': '800', 'answer19': '15%', 'answer20': '35%', 'answer21': '60', 'answer22': 'About the same.', 'answer23': 'Once a week', 'answer24': 'Dry food', 'answer25': 'Extremely familiar, I did my research.', 'answer26': '4', 'answer27': "Hill's Science Diet", 'answer28': 'Vet recommended, Max enjoys it, and good for his coat.', 'answer29': '4', 'answer30': '4', 'answer31': 'More indoor playtime.', 'answer32': 'Pandemic and bad weather', 'answer33': 'No, not interested.', 'answer34': 'No, staying home.', 'answer35': 'Not applicable', 'answer36': 'Female', 'answer37': '69', 'answer38': '1', 'answer39': 'High school graduate', 'answer40': 'Retired', 'answer41': '34000', 'answ ...
#
# 3
# [{'traits': 'Women aged 60+', 'answer1': '5', 'answer2': 'Beagle', 'answer3': '22', 'answer4': 'Molly', 'answer5': 'Named after my favorite childhood book character.', 'answer6': 'Molls', 'answer7': '2018', 'answer8': 'Yes', 'answer9': '8', 'answer10': 'It was love at first sight. I was overwhelmed with happiness.', 'answer11': 'Molly has brought a new level of joy and purpose into my life.', 'answer12': '5', 'answer13': 'Best friend', 'answer14': "Because she's not just a pet, she's part of the family.", 'answer15': 'Sit and stay, it took us about a week.', 'answer16': '14 hours, she sleeps in a cozy dog bed in the living room.', 'answer17': 'Yes', 'answer18': '$1500', 'answer19': '20%', 'answer20': '30%', 'answer21': '$120', 'answer22': 'Slightly more, I bought a new toy for her.', 'answer23': 'Every two weeks', 'answer24': 'Dry food', 'answer25': 'I am very familiar with the brand I use.', 'answer26': '5', 'answer27': 'Purina', 'answer28': 'Quality ingredients, recommended by a vet, and Molly loves it.', 'answer29': '4', 'answer30': '3', 'answer31': "We spend more time together, she's a comforting presence.", 'answer32': "The pandemic, as I'm at home more often.", 'answer33': 'No', 'answer34': 'Yes', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '62', 'answer38': '1', 'answer39': "Bachelor's Degree", 'answer40': 'Retired', 'answer41': '$45000', 'answer42': 'Austin, Texas'}, {'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Golden Retriever', 'answer3': '70', 'answer4': 'Duke', 'answer5': "He just looked like a 'Duke' when we saw him.", 'answer6': 'Dukie', 'answer7': '2016', 'answer8': 'No', 'answer9': '2', 'answer10': 'My heart was full, and I knew I had found a new companion.', 'answer11': 'He reminds me of the importance of unconditional love and living in the moment.', 'answer12': '5', 'answer13': 'Child', 'answer14': 'He is dependent on me, and the bond we share is very much like that of a parent and child.', 'answer15': "'Leave it', around three days to master.", 'answer16': '12 hours, he has his own bed in my bedroom.', 'answer17': 'No', 'answer18': '$2000', 'answer19': '25%', 'answer20': '40%', 'answer21': '$150', 'answer22': 'About the same.', 'answer23': 'Once a month', 'answer24': 'A mix', 'answer25': "I am somewhat familiar, I've done some research.", 'answer26': '4', 'answer27': 'Blue Buffalo', 'answer28': "It's healthy, Duke enjoys it, and I trust the brand.", 'answer29': '5', 'answer30': '4', 'answer31': 'Duke has been a source of stability and reassurance during unsettling times.', 'answer32': 'Recent political events and the general state of the world.', 'answer33': 'No', 'answer34': 'No', 'answer35': 'N/A', 'answer36': 'Female', 'answer37': '68', 'answer38': '2', 'answer39': 'Some College', 'answer40': 'Part-Time Employed', 'answer41': '$30000', 'answer42': 'Syracuse, New York'}, {'traits': 'Women aged 60+', 'answer1': '9', 'answer2': 'Labrador Retriever', 'answer3': '65', 'answer4': 'Bella', 'answer5': "She's beautiful, and 'Bella' means beautiful.", 'answer6': 'Bell', 'answer7': '2014', 'answer8': 'Yes', 'answer9': '5', 'answer10': 'Instant connection, it felt right.', 'answer11': "Bella's taught me to appreciate the little things in life more.", 'answer12': '5', 'answer13': 'Companion', 'answer14': "She's always by my side through thick and thin.", 'answer15': "Bella learned to 'play dead' after a month of casual training.", 'answer16': '10 hours, Bella loves sleeping by the fireplace.', 'answer17': 'Yes', 'answer18': '$1000', 'answer19': '10%', 'answer20': '50%', 'answer21': '$100', 'answer22': 'Increased due to some extra treats and a new leash.', 'answer23': 'Monthly', 'answer24': 'Dry food', 'answer25': "Extremely familiar, I've been using it for years.", 'answer26': '5', 'answer27': "Hill's Science Diet", 'answer28': 'Veterinarian approval, nutritional value, and company reputation.', 'answer29': '4', 'answer30': '2', 'answer31': "We're closer than ever before, she's my rock.", 'answer ...
#
# 5
# [{'traits': 'Women aged 60+', 'answer1': '14', 'answer2': 'Golden Retriever', 'answer3': '80', 'answer4': 'Buddy', 'answer5': "After my late husband's nickname for me.", 'answer6': 'Bud', 'answer7': '2010', 'answer8': 'Yes', 'answer9': '8 months', 'answer10': 'Overjoyed, like I found a missing piece of my heart.', 'answer11': "It's taught me that joy can be found in simple pleasures.", 'answer12': '5', 'answer13': 'Companion', 'answer14': 'Because he is a constant, comforting presence in my life.', 'answer15': 'Shake hands, about 2 weeks.', 'answer16': '14 hours, on his bed in the living room.', 'answer17': 'Yes', 'answer18': '$700', 'answer19': '20%', 'answer20': '50%', 'answer21': '$60', 'answer22': 'About the same', 'answer23': 'Monthly', 'answer24': 'Mix', 'answer25': 'Very familiar', 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': 'Quality ingredients, recommended by my vet, good reviews.', 'answer29': '4', 'answer30': '3', 'answer31': "More cuddle time since I'm staying in more.", 'answer32': 'The pandemic', 'answer33': 'No', 'answer34': 'No', 'answer35': 'Not applicable', 'answer36': 'Female', 'answer37': '65', 'answer38': '1', 'answer39': "Bachelor's degree", 'answer40': 'Retired', 'answer41': '$45,000', 'answer42': 'Sarasota, Florida'}, {'traits': 'Women aged 60+', 'answer1': '3', 'answer2': 'Poodle', 'answer3': '45', 'answer4': 'Coco', 'answer5': 'Her coat reminded me of chocolate.', 'answer6': 'Coco Puff', 'answer7': '2019', 'answer8': 'No', 'answer9': '7 months', 'answer10': 'Instant connection, it was love at first sight.', 'answer11': 'More laughter and spontaneity.', 'answer12': '5', 'answer13': 'Soulmate', 'answer14': 'She seems to understand me better than anyone else.', 'answer15': 'Play dead, 1 month of casual training.', 'answer16': '10 hours, cozy corner in my bedroom.', 'answer17': 'Yes', 'answer18': '$900', 'answer19': '30%', 'answer20': '40%', 'answer21': '$75', 'answer22': 'Slightly more as I spoiled her for her birthday.', 'answer23': 'Every two weeks', 'answer24': 'Dry', 'answer25': 'Extremely familiar', 'answer26': '5', 'answer27': 'Royal Canin', 'answer28': 'Formulated for her breed, high-quality standards, and she loves the taste.', 'answer29': '5', 'answer30': '4', 'answer31': "We've been on more walks, which has been great for both of us.", 'answer32': 'The pandemic, mostly.', 'answer33': 'Perhaps, if she shows interest.', 'answer34': 'Yes', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '68', 'answer38': '2', 'answer39': 'Some college', 'answer40': 'Part-time', 'answer41': '$30,000', 'answer42': 'Albuquerque, New Mexico'}, {'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Beagle', 'answer3': '25', 'answer4': 'Bailey', 'answer5': "She has the same warm, amber eyes as a Bailey's Irish Cream bottle.", 'answer6': 'Bails', 'answer7': '2016', 'answer8': 'Yes', 'answer9': '2 months', 'answer10': 'Nervous but excited, as if starting a new adventure.', 'answer11': 'I value the small moments more.', 'answer12': '5', 'answer13': 'Best friend', 'answer14': "She's been with me through ups and downs, always by my side.", 'answer15': 'Fetch, took a few days.', 'answer16': '12 hours, a dog bed in my study.', 'answer17': 'Yes', 'answer18': '$500', 'answer19': '10%', 'answer20': '60%', 'answer21': '$40', 'answer22': "It was lower, Bailey's food was on sale.", 'answer23': 'Biweekly', 'answer24': 'Dry', 'answer25': 'Somewhat familiar', 'answer26': '4', 'answer27': 'Purina', 'answer28': 'Affordability, availability, and she enjoys it.', 'answer29': '4', 'answer30': '2', 'answer31': 'No significant changes.', 'answer32': "I'm quite the homebody; nothing much has changed.", 'answer33': 'Doubtful, we prefer walks during that time.', 'answer34': 'No', 'answer35': "I don't travel much.", 'answer36': 'Female', 'answer37': '72', 'answer38': '1', 'answer39': 'High school diploma', 'answer40': 'Retired', 'answer41': '$25,000', 'answer42': 'Knoxville, Tennessee'}, {'traits': 'Women aged 60+', 'answer1': ...
#
# 3
# [{'traits': 'Women aged 60+', 'answer1': '11', 'answer2': 'Golden Retriever', 'answer3': '72', 'answer4': 'Sammy', 'answer5': 'Inspired by a favorite book character.', 'answer6': 'Sam', 'answer7': '2013', 'answer8': 'Yes', 'answer9': '8 months', 'answer10': 'Overwhelmed with joy.', 'answer11': 'She has made me more compassionate.', 'answer12': '5', 'answer13': 'Soulmate', 'answer14': "Because she's my constant companion.", 'answer15': 'Sit pretty - took about a week.', 'answer16': '14 hours, on her bed in the living room.', 'answer17': 'Yes', 'answer18': '$1500', 'answer19': '20%', 'answer20': '30%', 'answer21': '$130', 'answer22': 'About the same', 'answer23': 'Bi-weekly', 'answer24': 'Dry food', 'answer25': 'Very familiar', 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': 'Quality ingredients, recommended by vet.', 'answer29': '5', 'answer30': '2', 'answer31': 'More cuddle time during lockdowns.', 'answer32': 'The pandemic', 'answer33': 'No', 'answer34': 'No', 'answer35': '', 'answer36': 'Female', 'answer37': '65', 'answer38': '2', 'answer39': 'College degree', 'answer40': 'Retired', 'answer41': '$45,000', 'answer42': 'Sarasota, FL'}, {'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Beagle', 'answer3': '28', 'answer4': 'Cooper', 'answer5': 'Named after a character in a TV show I enjoy.', 'answer6': 'Coop', 'answer7': '2017', 'answer8': 'Yes', 'answer9': '12 weeks', 'answer10': 'Love at first sight.', 'answer11': "I've learned to live in the moment.", 'answer12': '5', 'answer13': 'Best friend', 'answer14': "He's loyal and always happy to see me.", 'answer15': 'Roll over - two weeks of training.', 'answer16': '10 hours, mainly on the couch.', 'answer17': 'Yes', 'answer18': '$700', 'answer19': '10%', 'answer20': '50%', 'answer21': '$60', 'answer22': 'Slightly fewer expenses', 'answer23': 'Once a month', 'answer24': 'Mix of dry and wet food', 'answer25': 'Extremely familiar', 'answer26': '4', 'answer27': "Hill's Science Diet", 'answer28': 'Vet recommendation, age-specific formula, good value.', 'answer29': '4', 'answer30': '3', 'answer31': "I'm more attentive and take fewer risks.", 'answer32': 'COVID-19 concerns', 'answer33': 'Perhaps, if it interests him.', 'answer34': 'Yes', 'answer35': 'By car', 'answer36': 'Female', 'answer37': '68', 'answer38': '1', 'answer39': 'Some college', 'answer40': 'Self-employed', 'answer41': '$60,000', 'answer42': 'Chapel Hill, NC'}, {'traits': 'Women aged 60+', 'answer1': '4', 'answer2': 'Labrador Retriever', 'answer3': '65', 'answer4': 'Max', 'answer5': "It's just a name I've always liked.", 'answer6': 'Maxie', 'answer7': '2019', 'answer8': 'No, purchased from a breeder', 'answer9': '7 months', 'answer10': 'It was like meeting a new family member.', 'answer11': 'My dog has brought me an immense sense of purpose.', 'answer12': '4', 'answer13': 'Companion', 'answer14': 'We share our lives but have our own independence.', 'answer15': 'Fetch, one month to perfect it.', 'answer16': '12 hours, in a dog bed by my own.', 'answer17': 'Yes', 'answer18': '$1200', 'answer19': '15%', 'answer20': '40%', 'answer21': '$100', 'answer22': 'A bit more due to stocking up.', 'answer23': 'Every two weeks', 'answer24': 'Dry food', 'answer25': 'Somewhat familiar', 'answer26': '3', 'answer27': 'Purina Pro Plan', 'answer28': "It's what the breeder recommended, Max enjoys it.", 'answer29': '4', 'answer30': '4', 'answer31': 'Increased walks for both our healths.', 'answer32': 'The need for social distancing', 'answer33': 'No, not particularly interested.', 'answer34': 'Maybe a short trip', 'answer35': "By car, it's easier with Max.", 'answer36': 'Female', 'answer37': '71', 'answer38': '1', 'answer39': 'High school graduate', 'answer40': 'Part-time', 'answer41': '$35,000', 'answer42': 'Boulder, CO'}]
#
# 1
# [{'traits': 'Women aged 60+', 'answer1': '3', 'answer2': 'Labrador Retriever', 'answer3': '70', 'answer4': 'Scout', 'answer5': 'To Kill a Mockingbird', 'answer6': 'Scoutie', 'answer7': '2018', 'answer8': 'Yes', 'answer9': '8', 'answer10': 'Ecstatic', 'answer11': 'Gives me a reason to wake up every morning', 'answer12': '5', 'answer13': 'Companion', 'answer14': "She's always by my side", 'answer15': 'Sit, 3 weeks', 'answer16': 'About 14 hours, in my bedroom', 'answer17': 'Yes', 'answer18': '$1200', 'answer19': '25%', 'answer20': '50%', 'answer21': '$100', 'answer22': 'Slightly less, had leftover supplies', 'answer23': 'Every two weeks', 'answer24': 'Mix', 'answer25': 'I know it well', 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': 'Quality ingredients, vet recommendation', 'answer29': '4', 'answer30': '3', 'answer31': 'More cuddle time', 'answer32': 'The pandemic', 'answer33': 'No', 'answer34': 'No', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '65', 'answer38': '2', 'answer39': 'Some college', 'answer40': 'Retired', 'answer41': '$45,000', 'answer42': 'Austin, Texas'}]
#
# 3
# [{'traits': 'Women aged 60+', 'answer1': '3', 'answer2': 'Beagle', 'answer3': '22', 'answer4': 'Baxter', 'answer5': "He's named after a character from a book I love.", 'answer6': 'Bax', 'answer7': 'I got him two years ago.', 'answer8': 'Yes', 'answer9': '8', 'answer10': 'It was love at first lick!', 'answer11': 'He reminds me daily to live in the moment and enjoy the simple things.', 'answer12': '5', 'answer13': 'Companion', 'answer14': "Because he's my faithful sidekick through thick and thin.", 'answer15': "'Spin around,' it took him about a week to get it.", 'answer16': 'He sleeps for roughly 14 hours and he has a cozy bed in my bedroom.', 'answer17': 'Yes', 'answer18': '750', 'answer19': '25%', 'answer20': '40%', 'answer21': '60', 'answer22': 'I spent a bit more in March because of his grooming appointment.', 'answer23': 'Every three weeks', 'answer24': 'A mix of both', 'answer25': "I'm very familiar; I've researched it thoroughly.", 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': 'Quality ingredients, trusted brand, and his coat looks great on it.', 'answer29': '5', 'answer30': '3', 'answer31': "We spend even more time together now; he's a comforting presence.", 'answer32': 'The pandemic, mostly.', 'answer33': "No, he doesn't much care for the TV.", 'answer34': 'Yes', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '65', 'answer38': '1', 'answer39': 'Some college', 'answer40': 'Retired', 'answer41': '45000', 'answer42': 'Sarasota, FL'}, {'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Labrador Retriever', 'answer3': '78', 'answer4': 'Molly', 'answer5': "It was my grandmother's name, and it just seemed to suit her perfectly.", 'answer6': 'Molls', 'answer7': '2014', 'answer8': 'No', 'answer9': '6', 'answer10': 'I was over the moon; she was so gentle and friendly.', 'answer11': "She's my reason to wake up every morning with a smile.", 'answer12': '5', 'answer13': 'Soulmate', 'answer14': 'She understands me better than most humans do.', 'answer15': "'Fetch the paper,' and it took a couple of months - she likes to take her time!", 'answer16': 'On average 12 hours, on a dog bed in the living room.', 'answer17': 'Absolutely', 'answer18': '1200', 'answer19': '20%', 'answer20': '30%', 'answer21': '90', 'answer22': 'Roughly the same, February was a bit cheaper since she had no vet visits.', 'answer23': 'Once a month', 'answer24': 'Dry food', 'answer25': 'I rely on recommendations but also read the labels myself.', 'answer26': '4', 'answer27': 'Purina Pro Plan', 'answer28': "Her vet recommended it, she enjoys it, and I've seen positive health effects.", 'answer29': '4', 'answer30': '4', 'answer31': 'Not significantly, but we make sure to keep social distancing.', 'answer32': 'COVID-19 and the related restrictions.', 'answer33': 'If it happens to be on, sure.', 'answer34': "Not this year, we're staying put.", 'answer35': 'N/A', 'answer36': 'Female', 'answer37': '72', 'answer38': '2', 'answer39': "Bachelor's degree", 'answer40': 'Retired', 'answer41': '60000', 'answer42': 'Austin, TX'}, {'traits': 'Women aged 60+', 'answer1': '12', 'answer2': 'Golden Retriever', 'answer3': '55', 'answer4': 'Sunny', 'answer5': 'His golden fur shines like the sun, even on cloudy days.', 'answer6': 'Sun', 'answer7': "I've had him since he was a puppy, so about 12 years now.", 'answer8': 'Yes', 'answer9': '2', 'answer10': 'I felt like I had found a new best friend who needed me as much as I needed him.', 'answer11': 'Sunny has taught me that loyalty and joy are the essence of life.', 'answer12': '5', 'answer13': 'Partner', 'answer14': "We've been through a lot together, and he's always there for me.", 'answer15': "'Give hugs,' and it took no time at all - he's a natural hugger.", 'answer16': 'He naps about 16 hours and prefers the foot of my bed.', 'answer17': 'Yes I do', 'answer18': '700', 'answer19': '30%', 'answer20': '35%', 'answer21': '70', 'answer22': "I didn't really keep track, but I assume it's about the same.", 'answer23':  ...
#
# 1
# [{'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Beagle', 'answer3': '28', 'answer4': 'Baxter', 'answer5': 'Named after a beloved childhood pet.', 'answer6': 'Bax', 'answer7': '2015', 'answer8': 'Yes', 'answer9': '8 months', 'answer10': 'I was overwhelmed with joy.', 'answer11': "I've become much more active and social.", 'answer12': '5', 'answer13': 'Companion', 'answer14': "She's my constant friend.", 'answer15': "'Stay', in about a week.", 'answer16': '14 hours, on the living room couch.', 'answer17': 'Yes', 'answer18': '$1200', 'answer19': '25%', 'answer20': '40%', 'answer21': '$90', 'answer22': 'Slightly more, due to buying a new toy.', 'answer23': 'Every two weeks', 'answer24': 'Mix of both', 'answer25': "I'm very familiar with it.", 'answer26': '5', 'answer27': 'Blue Buffalo', 'answer28': "Quality ingredients, dog's preference, and good reviews.", 'answer29': '5', 'answer30': '3', 'answer31': "More cuddle time since I'm home more.", 'answer32': 'COVID-19 pandemic', 'answer33': 'No', 'answer34': 'No', 'answer35': 'Not applicable', 'answer36': 'Female', 'answer37': '65', 'answer38': '2', 'answer39': "Bachelor's degree", 'answer40': 'Retired', 'answer41': '$60000', 'answer42': 'Austin, Texas'}]
#
# 3
# [{'traits': 'Women aged 60+', 'answer1': '7', 'answer2': 'Golden Retriever', 'answer3': '65', 'answer4': 'Bailey', 'answer5': 'After my favorite childhood book character', 'answer6': 'Bails', 'answer7': '2015', 'answer8': 'Yes', 'answer9': '2 months', 'answer10': 'Instant connection, it was love at first sight', 'answer11': "He's brought so much joy, I appreciate the little things more", 'answer12': '5', 'answer13': 'Companion', 'answer14': 'Because Bailey is always by my side, giving comfort', 'answer15': 'Sit pretty, took about a week', 'answer16': '14 hours, mainly in the living room on her bed', 'answer17': 'Yes', 'answer18': '$1200', 'answer19': '20%', 'answer20': '30%', 'answer21': '$100', 'answer22': 'A little more, due to buying a new bed', 'answer23': 'Monthly', 'answer24': 'Dry food', 'answer25': 'I know the brand very well', 'answer26': '5', 'answer27': 'Purina', 'answer28': 'Quality ingredients, veterinarian recommended, dog likes it', 'answer29': '4', 'answer30': '3', 'answer31': 'We spend more quality time together', 'answer32': 'The pandemic', 'answer33': 'Yes', 'answer34': 'Yes', 'answer35': 'Car', 'answer36': 'Female', 'answer37': '63', 'answer38': '2', 'answer39': "Bachelor's degree", 'answer40': 'Retired', 'answer41': '$60,000', 'answer42': 'Savannah, Georgia'}, {'traits': 'Women aged 60+', 'answer1': '4', 'answer2': 'Shih Tzu', 'answer3': '12', 'answer4': 'Gizmo', 'answer5': 'He reminded me of the Gremlins movie character', 'answer6': 'Gizzy', 'answer7': '2019', 'answer8': 'No', 'answer9': '4 months', 'answer10': 'Ecstatic, he was adorable', 'answer11': "He's taught me to be more patient and caring", 'answer12': '5', 'answer13': 'Soulmate', 'answer14': 'Gizmo is a great comfort, he understands me perfectly', 'answer15': 'High five, two days', 'answer16': '16 hours, in my bedroom on his plush cushion', 'answer17': 'Yes', 'answer18': '$800', 'answer19': '25%', 'answer20': '40%', 'answer21': '$90', 'answer22': 'Roughly the same', 'answer23': 'Every three weeks', 'answer24': 'Mix', 'answer25': 'Somewhat familiar', 'answer26': '4', 'answer27': 'Blue Buffalo', 'answer28': 'Nutritious, small kibble size, good reviews', 'answer29': '5', 'answer30': '4', 'answer31': "I'm more cautious about where we go", 'answer32': 'COVID-related restrictions', 'answer33': 'Maybe'}, {'traits': 'Women aged 60+', 'answer1': '3', 'answer2': 'Beagle', 'answer3': '20', 'answer4': 'Charlie', 'answer5': 'Just always liked the name', 'answer6': 'Char', 'answer7': '2020', 'answer8': 'Yes', 'answer9': '9 months', 'answer10': 'Nervous, but excited', 'answer11': 'I feel less alone, more active', 'answer12': '5', 'answer13': 'Family', 'answer14': "Charlie is not just a pet, he's my family", 'answer15': 'Fetch, a couple of days', 'answer16': '12 hours, his cozy crate in the kitchen', 'answer17': 'Yes', 'answer18': '$500', 'answer19': '10%', 'answer20': '50%', 'answer21': '$45', 'answer22': 'Increased slightly, got some new toys', 'answer23': 'Bi-weekly', 'answer24': 'Dry food', 'answer25': 'Very familiar', 'answer26': '3', 'answer27': "Hill's Science Diet", 'answer28': 'Recommended by my vet, fits my budget, dog enjoys it', 'answer29': '5', 'answer30': '2', 'answer31': 'More snuggling on the couch', 'answer32': 'The winter season', 'answer33': 'No', 'answer34': 'No'}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 52
#      50     lst = [data['traits'], person_number]
#      51     for ind, question in enumerate(questions):
# ---> 52         lst.append(data[f'answer{ind+1}'])
#      53     write_csv(output_file, lst)
#      54 for data in final_responses:
#
# KeyError: 'answer34'

# %%
resp = [{'a':1,'b':2}, {'c':3, 'd':4}, 'a', 'b']

# %%
final_resp = []
for data in resp:
    if type(data) == dict:
        final_resp.append(data)
final_resp
# Out:
# [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]
